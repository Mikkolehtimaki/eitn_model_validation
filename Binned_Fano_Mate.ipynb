# %%
import numpy as np

datas=[data1,data2,data3,data4,data5,data6]


for j in datas:
    data_exc, eIds = get_neuron_type(j, 'exc')
    data_inh, iIds = get_neuron_type(j, 'inh')
    counter2=[]
    for x in range(20):
        counter=[]
        for i in j:
            counter.append(len([y for y in i if  y>=5*x and y<5*(x+1)]))
        firing_rate=np.divide(counter, 5.0)
        #print(" ")
        counter2.append(np.var(firing_rate)/np.mean(firing_rate))
    print(counter2)
